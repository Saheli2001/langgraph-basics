# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI()

# %%
class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    question = state['question']
    prompt = f"Answer the following question: {question}"
    answer = model.invoke(prompt).content
    state['answer'] = answer

    return state

# %%
# graph

graph = StateGraph(LLMState)

graph.add_node('llm_qa', llm_qa)

graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa', END)

workflow = graph.compile()

# %%
initial_state = {'question': 'Whats the colour of moon?'}

# %%
workflow.invoke(initial_state)
# Out:
# {'question': 'Whats the colour of moon?',
#  'answer': 'The moon is typically a pale white or grey color.'}

# %%
model.invoke('Whats the colour of moon?').content
# Out:
# 'The color of the moon appears to be gray or white when viewed from Earth. This is because the moon reflects light from the sun and does not emit its own light.'
